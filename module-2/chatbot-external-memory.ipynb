# %% [markdown]
# [![Open in Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/langchain-ai/langchain-academy/blob/main/module-2/chatbot-external-memory.ipynb) [![Open in LangChain Academy](https://cdn.prod.website-files.com/65b8cd72835ceeacd4449a53/66e9eba12c7b7688aa3dbb5e_LCA-badge-green.svg)](https://academy.langchain.com/courses/take/intro-to-langgraph/lessons/58239440-lesson-6-chatbot-w-summarizing-messages-and-external-memory)

# %% [markdown]
# # Chatbot with message summarization & external DB memory
#
# ## Review
#
# We've covered how to customize graph state schema and reducer.
#
# We've also shown a number of tricks for trimming or filtering messages in graph state.
#
# We've used these concepts in a Chatbot with memory that produces a running summary of the conversation.
#
# ## Goals
#
# But, what if we want our Chatbot to have memory that persists indefinitely?
#
# Now, we'll introduce some more advanced checkpointers that support external databases.
#
# Here, we'll show how to use [Sqlite as a checkpointer](https://langchain-ai.github.io/langgraph/concepts/low_level/#checkpointer), but other checkpointers, such as [Postgres](https://langchain-ai.github.io/langgraph/how-tos/persistence_postgres/) are available!

# %%
# %%capture --no-stderr
# %pip install --quiet -U langgraph-checkpoint-sqlite langchain_core langgraph langchain_openai

# %%
import os, getpass

def _set_env(var: str):
    if not os.environ.get(var):
        os.environ[var] = getpass.getpass(f"{var}: ")

_set_env("OPENAI_API_KEY")

# %% [markdown]
# ## Sqlite
#
# A good starting point here is the [SqliteSaver checkpointer](https://langchain-ai.github.io/langgraph/concepts/low_level/#checkpointer).
#
# Sqlite is a [small, fast, highly popular](https://x.com/karpathy/status/1819490455664685297) SQL database.
#
# If we supply `":memory:"` it creates an in-memory Sqlite database.

# %%
import sqlite3
# In memory
conn = sqlite3.connect(":memory:", check_same_thread = False)

# %% [markdown]
# But, if we supply a db path, then it will create a database for us!

# %%
# pull file if it doesn't exist and connect to local db
#!mkdir -p state_db && [ ! -f state_db/example.db ] && wget -P state_db https://github.com/langchain-ai/langchain-academy/raw/main/module-2/state_db/example.db

db_path = "state_db/example.db"
conn = sqlite3.connect(db_path, check_same_thread=False)

# %%
# Here is our checkpointer 
from langgraph.checkpoint.sqlite import SqliteSaver
memory = SqliteSaver(conn)

# %% [markdown]
# Let's re-define our chatbot.

# %%
from langchain_openai import ChatOpenAI
from langchain_core.messages import SystemMessage, HumanMessage, RemoveMessage

from langgraph.graph import END
from langgraph.graph import MessagesState

model = ChatOpenAI(
    model="local-llama",
    openai_api_base="http://127.0.0.1:8080/v1",
    openai_api_key="none"
)

class State(MessagesState):
    summary: str

# Define the logic to call the model
def call_model(state: State):
    
    # Get summary if it exists
    summary = state.get("summary", "")

    # If there is summary, then we add it
    if summary:
        
        # Add summary to system message
        system_message = f"Summary of conversation earlier: {summary}"

        # Append summary to any newer messages
        messages = [SystemMessage(content=system_message)] + state["messages"]
    
    else:
        messages = state["messages"]
    
    response = model.invoke(messages)
    return {"messages": response}

def summarize_conversation(state: State):
    
    # First, we get any existing summary
    summary = state.get("summary", "")

    # Create our summarization prompt 
    if summary:
        
        # A summary already exists
        summary_message = (
            f"This is summary of the conversation to date: {summary}\n\n"
            "Extend the summary by taking into account the new messages above:"
        )
        
    else:
        summary_message = "Create a summary of the conversation above:"

    # Add prompt to our history
    messages = state["messages"] + [HumanMessage(content=summary_message)]
    response = model.invoke(messages)
    
    # Delete all but the 2 most recent messages
    delete_messages = [RemoveMessage(id=m.id) for m in state["messages"][:-2]]
    return {"summary": response.content, "messages": delete_messages}

# Determine whether to end or summarize the conversation
def should_continue(state: State):
    
    """Return the next node to execute."""
    
    messages = state["messages"]
    
    # If there are more than six messages, then we summarize the conversation
    if len(messages) > 6:
        return "summarize_conversation"
    
    # Otherwise we can just end
    return END

# %% [markdown]
# Now, we just re-compile with our sqlite checkpointer.

# %%
from IPython.display import Image, display
from langgraph.graph import StateGraph, START

# Define a new graph
workflow = StateGraph(State)
workflow.add_node("conversation", call_model)
workflow.add_node(summarize_conversation)

# Set the entrypoint as conversation
workflow.add_edge(START, "conversation")
workflow.add_conditional_edges("conversation", should_continue)
workflow.add_edge("summarize_conversation", END)

# Compile
graph = workflow.compile(checkpointer=memory)
display(Image(graph.get_graph().draw_mermaid_png()))

# %% [markdown]
# Now, we can invoke the graph several times.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}

# Start conversation
input_message = HumanMessage(content="hi! I'm Jebin")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()

input_message = HumanMessage(content="what's my name?")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()

input_message = HumanMessage(content="i like the 49ers!")
output = graph.invoke({"messages": [input_message]}, config) 
for m in output['messages'][-1:]:
    m.pretty_print()
# Out:
# ================================== Ai Message ==================================
#
# Hello Jebin! Nice to meet you. Is there a particular topic or aspect of the San Francisco 49ers you're interested in discussing?
# ================================== Ai Message ==================================
#
# Your name is Jebin. How can I assist you today regarding the San Francisco 49ers?
# ================================== Ai Message ==================================
#
# That's great to hear! Do you have a particular aspect of the San Francisco 49ers you're interested in discussing, such as their history, current roster, recent games, or any other topic?

# %% [markdown]
# Let's confirm that our state is saved locally.

# %%
config = {"configurable": {"thread_id": "1"}}
graph_state = graph.get_state(config)
graph_state
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="hi! I'm Jebin", additional_kwargs={}, response_metadata={}, id='a6e0d4f9-37fb-4c88-a051-2a4acf5d1eaa'), AIMessage(content="Hello Jebin! Nice to meet you. Is there a particular topic or aspect of the San Francisco 49ers you're interested in discussing?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 31, 'prompt_tokens': 624, 'total_tokens': 655, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'local-llama', 'system_fingerprint': 'b5973-a86f52b2', 'id': 'chatcmpl-X1Brd6IeK6GWi8enGgwCE8nch1Eh4Voo', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--e9d3872a-1eaf-477f-adce-79f9b85f5655-0', usage_metadata={'input_tokens': 624, 'output_tokens': 31, 'total_tokens': 655, 'input_token_details': {}, 'output_token_details': {}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='38e48ea0-8b69-4705-ae1e-e5dbec5904fb'), AIMessage(content='Your name is Jebin. How can I assist you today regarding the San Francisco 49ers?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 22, 'prompt_tokens': 530, 'total_tokens': 552, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'local-llama', 'system_fingerprint': 'b5973-a86f52b2', 'id': 'chatcmpl-KzgRQRu0Kk9Fw7yxp1rTxaoAvWwErcOo', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--40cef5b3-d7db-4516-9f66-082de237b6e7-0', usage_metadata={'input_tokens': 530, 'output_tokens': 22, 'total_tokens': 552, 'input_token_details': {}, 'output_token_details': {}}), HumanMessage(content='i like the 49ers!', additional_kwargs={}, response_metadata={}, id='884fb142-032f-49d0-bddf-88ee5a000b48'), AIMessage(content="That's great to hear! Do you have a particular aspect of the San Francisco 49ers you're interested in discussing, such as their history, current roster, recent games, or any other topic?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 43, 'prompt_tokens': 569, 'total_tokens': 612, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'local-llama', 'system_fingerprint': 'b5973-a86f52b2', 'id': 'chatcmpl-2k8m8oe2kuhZSc8bB3UHW2kfxmcwR1qK', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--47da584d-b136-4aed-b262-d1c140c83abe-0', usage_metadata={'input_tokens': 569, 'output_tokens': 43, 'total_tokens': 612, 'input_token_details': {}, 'output_token_details': {}})], 'summary': 'Sure, here\'s an extended summary of the conversation based on the new messages:\n\n- Jebin introduced himself by saying, "hi! I\'m Jebin."\n- The AI assistant acknowledged Jebin\'s introduction and showed willingness to discuss the San Francisco 49ers, asking if there was a particular aspect of the 49ers Jebin was interested in.\n- Jebin expressed his interest in the 49ers by saying, "I like the 49ers!"\n- Following Jebin\'s statement, the AI assistant offered to discuss various topics related to the 49ers, including their history, current roster, or recent games.\n- Jebin responded positively, indicating an interest in discussing the 49ers.\n- The AI assistant mentioned the San Francisco 49ers, noting that the team is a fantastic choice. The assistant asked if there was a particular aspect of the 49ers Jebin wanted to discuss.\n- Jebin did not provide a specific topic but showed interest in discussing the 49ers.\n- The conversation then briefly touched on the team, noting the AI assistant mentioned the San Francisco 49ers and asked if Jebin had any specific questions or topics in mind.\n- Jebin re-introduced himself by saying, "hi! I\'m Jebin."\n- Jebin re-introduced himself at the end of the summary, indicating the conversation was about to end.\n\nIn summary:\n- Jebin introduced himself by saying, "hi! I\'m Jebin."\n- The AI assistant acknowled ...

# %% [markdown]
# ### Persisting state
#
# Using database like Sqlite means state is persisted!
#
# For example, we can re-start the notebook kernel and see that we can still load from Sqlite DB on disk.

# %%
# Create a thread
config = {"configurable": {"thread_id": "1"}}
graph_state = graph.get_state(config)
graph_state
# Out:
# StateSnapshot(values={'messages': [HumanMessage(content="hi! I'm Jebin", additional_kwargs={}, response_metadata={}, id='edb01292-14e3-4298-8cb5-9b0bbe342b8e'), AIMessage(content="Hello Jebin! It looks like you're reintroducing yourself. Is there a particular topic or question you'd like to discuss today? I was just about to start a conversation about the San Francisco 49ers if that's okay. Let me know if you'd like to continue with that or if you have any other topic in mind.", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 70, 'prompt_tokens': 362, 'total_tokens': 432, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'local-llama', 'system_fingerprint': 'b5973-a86f52b2', 'id': 'chatcmpl-onuHrpVoML9imSSXWwfBHEWfjr8HM7z1', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--137666a2-3dad-47b8-a8c1-6f15f68a697d-0', usage_metadata={'input_tokens': 362, 'output_tokens': 70, 'total_tokens': 432, 'input_token_details': {}, 'output_token_details': {}}), HumanMessage(content="what's my name?", additional_kwargs={}, response_metadata={}, id='62f5ae2e-2492-4fef-8cd7-ad8425456060'), AIMessage(content='Your name is Jebin. Is there something specific you would like to discuss related to the San Francisco 49ers, or would you like to talk about something else?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 349, 'total_tokens': 385, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'local-llama', 'system_fingerprint': 'b5973-a86f52b2', 'id': 'chatcmpl-oAKQZOojBxpZhCL33ECFfSKPX6ctHKZw', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--8e29b1bc-8433-484a-a08f-8c6b4c141669-0', usage_metadata={'input_tokens': 349, 'output_tokens': 36, 'total_tokens': 385, 'input_token_details': {}, 'output_token_details': {}}), HumanMessage(content='i like the 49ers!', additional_kwargs={}, response_metadata={}, id='1a7e10d2-41b8-4095-906a-d94a8c4f6af0'), AIMessage(content="That's great to hear! The San Francisco 49ers are a fantastic team. Do you have a particular aspect of the 49ers you're interested in discussing, such as their history, current roster, recent games, or any memorable moments?", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 53, 'prompt_tokens': 402, 'total_tokens': 455, 'completion_tokens_details': None, 'prompt_tokens_details': None}, 'model_name': 'local-llama', 'system_fingerprint': 'b5973-a86f52b2', 'id': 'chatcmpl-7AiyRl8mKOovydI1tbcpTOnszvOvgvUp', 'service_tier': None, 'finish_reason': 'stop', 'logprobs': None}, id='run--5965ec8a-fe25-483b-b775-65f86c89565a-0', usage_metadata={'input_tokens': 402, 'output_tokens': 53, 'total_tokens': 455, 'input_token_details': {}, 'output_token_details': {}})], 'summary': 'Sure, here\'s an extended summary of the conversation:\n\nThe conversation began with Jebin introducing himself by saying, "hi! I\'m Jebin." The AI assistant acknowledged Jebin\'s introduction and showed willingness to discuss the San Francisco 49ers, asking if there was a particular aspect of the 49ers Jebin was interested in. Jebin expressed his interest in the 49ers by saying, "I like the 49ers!"\n\nFollowing Jebin\'s statement, the AI assistant offered to discuss various topics related to the 49ers, including their history, current roster, or memorable games. Jebin responded positively, indicating an interest in discussing the 49ers. The conversation then briefly touched on the team, but Jebin reintroduced himself at the end of the brief exchange.\n\nIn summary:\n- Jebin introduced himself.\n- The AI assistant acknowledged and expressed interest in discussing the 49ers.\n- Jebin mentioned liking the 49ers.\n- The AI assistant offered to discuss various aspects of the 49ers.\n- Jebin showed interest in discussing the 49ers.\n- The conversation ended with Jebin rei ...

# %% [markdown]
# ## LangGraph Studio
#
# **⚠️ DISCLAIMER**
#
# Since the filming of these videos, we've updated Studio so that it can be run locally and opened in your browser. This is now the preferred way to run Studio (rather than using the Desktop App as shown in the video). See documentation [here](https://langchain-ai.github.io/langgraph/concepts/langgraph_studio/#local-development-server) on the local development server and [here](https://langchain-ai.github.io/langgraph/how-tos/local-studio/#run-the-development-server). To start the local development server, run the following command in your terminal in the `/studio` directory in this module:
#
# ```
# langgraph dev
# ```
#
# You should see the following output:
# ```
# - 🚀 API: http://127.0.0.1:2024
# - 🎨 Studio UI: https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024
# - 📚 API Docs: http://127.0.0.1:2024/docs
# ```
#
# Open your browser and navigate to the Studio UI: `https://smith.langchain.com/studio/?baseUrl=http://127.0.0.1:2024`.
